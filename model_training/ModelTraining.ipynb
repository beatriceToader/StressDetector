# %%
#uninstall the current version of scikit-learn
# !pip uninstall scikit-learn -y

#install the version of scikit-learn that is compatible with AWS
# !pip install scikit-learn==1.5.0

#check the installation
import sklearn
print(sklearn.__version__)
# Out:
# Found existing installation: scikit-learn 1.2.2
# Uninstalling scikit-learn-1.2.2:
#   Successfully uninstalled scikit-learn-1.2.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 57.5 MB/s eta 0:00:00
# ...
# 1.5.0

# %%
#import the needed libraries
import numpy as np
import pandas as pd
import os
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
#unzip the dataset and read the data
# !unzip merged_data.csv.zip

data = pd.read_csv('merged_data.csv')
data
# Out:
# <ipython-input-5-b6f47101a203>:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('merged_data.csv')
#              X     Y     Z       EDA     HR   TEMP  id  \
# 0        -13.0 -61.0   5.0  6.769995  99.43  31.17  15
# 1        -20.0 -69.0  -3.0  6.769995  99.43  31.17  15
# 2        -31.0 -78.0 -15.0  6.769995  99.43  31.17  15
# 3        -47.0 -65.0 -38.0  6.769995  99.43  31.17  15
# 4        -67.0 -57.0 -53.0  6.769995  99.43  31.17  15
# ...        ...   ...   ...       ...    ...    ...  ..
# 11509046 -16.0 -56.0  24.0  3.386070  88.37  33.77  F5
# 11509047  -8.0 -50.0  27.0  3.386070  88.37  33.77  F5
# 11509048 -28.0 -36.0  28.0  3.386070  88.37  33.77  F5
# 11509049 -29.0 -29.0  30.0  3.386070  88.37  33.77  F5
# 11509050 -22.0 -24.0  29.0  3.374543  88.33  33.75  F5
#
#                                datetime  label
# 0         2020-07-08 14:03:00.000000000    2.0
# ...

# %%
#drop the columns that are unnecessary
data.drop(["X","Y","Z","id","datetime"], axis=1, inplace=True)
data
# Out:
#                EDA     HR   TEMP  label
# 0         6.769995  99.43  31.17    2.0
# 1         6.769995  99.43  31.17    2.0
# 2         6.769995  99.43  31.17    2.0
# 3         6.769995  99.43  31.17    2.0
# 4         6.769995  99.43  31.17    2.0
# ...            ...    ...    ...    ...
# 11509046  3.386070  88.37  33.77    2.0
# 11509047  3.386070  88.37  33.77    2.0
# 11509048  3.386070  88.37  33.77    2.0
# 11509049  3.386070  88.37  33.77    2.0
# 11509050  3.374543  88.33  33.75    2.0
#
# [11509051 rows x 4 columns]

# %%
#check for NaN values
data.isna().sum()
# Out:
# EDA      0
# HR       0
# TEMP     0
# label    0
# dtype: int64

# %%
#drop the NaN values
data = data.dropna()

# %%
#check for duplicated lines
data.duplicated().sum()
# Out:
# 10275774

# %%
#erase the duplicates
data = data.drop_duplicates()

# %%
#randomize the rows
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#                EDA     HR   TEMP  label
# 0         4.907579  75.80  33.50    2.0
# 1         0.619182  80.53  33.79    0.0
# 2         0.310330  72.80  34.73    0.0
# 3        26.048630  93.15  32.27    2.0
# 4         9.444842  84.83  33.50    0.0
# ...            ...    ...    ...    ...
# 1233272   9.557889  86.12  35.49    2.0
# 1233273   9.963582  85.47  34.57    2.0
# 1233274   5.729494  88.07  34.03    2.0
# 1233275  14.326116  91.40  34.71    2.0
# 1233276   4.895878  80.73  30.95    2.0
#
# [1233277 rows x 4 columns]

# %%
#break the data in features and labels for training
features = data[['EDA','HR','TEMP']]
labels = data['label']

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

#train the model
clf = RandomForestClassifier(n_estimators=100, max_depth=20, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, random_state=42)

# %%
#visualize the model's performance
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Precision:', precision_score(y_test, y_pred, average='weighted'))
print('Recall:', recall_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy: 0.9380311040477426
# Precision: 0.9395775873573506
# Recall: 0.9380311040477426
